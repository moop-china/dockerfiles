# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([1, 2, 3, 4])
plt.ylabel('中文测试')
plt.xlabel('中文测试')
plt.show()

# %% [markdown]
# # 中文测试
# 中文测试
#
# 中文测试
#
# 中文测试
#
# 中文测试
#
# 中文测试
#
# 中文测试
#
# 中文测试
